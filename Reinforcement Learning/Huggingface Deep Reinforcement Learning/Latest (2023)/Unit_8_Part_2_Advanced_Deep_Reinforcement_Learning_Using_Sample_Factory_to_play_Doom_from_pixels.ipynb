# %% [markdown]
# # Unit 8 Part 2: Advanced Deep Reinforcement Learning. Using Sample Factory to play Doom from pixels
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/thumbnail2.png" alt="Thumbnail"/>
#
# In this notebook, we will learn how to train a Deep Neural Network to collect objects in a 3D environment based on the game of Doom, a video of the resulting policy is shown below. We train this policy using [Sample Factory](https://www.samplefactory.dev/), an asynchronous implementation of the PPO algorithm.
#
# Please note the following points:
#
# *   [Sample Factory](https://www.samplefactory.dev/) is an advanced RL framework and **only functions on Linux and Mac** (not Windows).
#
# *  The framework performs best on a **GPU machine with many CPU cores**, where it can achieve speeds of 100k interactions per second. The resources available on a standard Colab notebook **limit the performance of this library**. So the speed in this setting **does not reflect the real-world performance**.
# * Benchmarks for Sample Factory are available in a number of settings, check out the [examples](https://github.com/alex-petrenko/sample-factory/tree/master/sf_examples) if you want to find out more.

# %%
from IPython.display import HTML

HTML('''<video width="640" height="480" controls>
  <source src="https://huggingface.co/edbeeching/doom_health_gathering_supreme_3333/resolve/main/replay.mp4" 
  type="video/mp4">Your browser does not support the video tag.</video>'''
)
# Out:
# <video width="640" height="480" controls>
#   <source src="https://huggingface.co/edbeeching/doom_health_gathering_supreme_3333/resolve/main/replay.mp4"
#   type="video/mp4">Your browser does not support the video tag.</video>

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push one model:
#
# - `doom_health_gathering_supreme` get a result of >= 5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# If you don't find your model, **go to the bottom of the page and click on the refresh button**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# Before starting to train our agent, let's **study the library and environments we're going to use**.
#
# ## Sample Factory
#
# [Sample Factory](https://www.samplefactory.dev/) is one of the **fastest RL libraries focused on very efficient synchronous and asynchronous implementations of policy gradients (PPO)**.
#
# Sample Factory is thoroughly **tested, used by many researchers and practitioners**, and is actively maintained. Our implementation is known to **reach SOTA performance in a variety of domains while minimizing RL experiment training time and hardware requirements**.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/samplefactoryenvs.png" alt="Sample factory"/>
#
#
#
# ### Key features
#
# - Highly optimized algorithm [architecture](https://www.samplefactory.dev/06-architecture/overview/) for maximum learning throughput
# - [Synchronous and asynchronous](https://www.samplefactory.dev/07-advanced-topics/sync-async/) training regimes
# - [Serial (single-process) mode](https://www.samplefactory.dev/07-advanced-topics/serial-mode/) for easy debugging
# - Optimal performance in both CPU-based and [GPU-accelerated environments](https://www.samplefactory.dev/09-environment-integrations/isaacgym/)
# - Single- & multi-agent training, self-play, supports [training multiple policies](https://www.samplefactory.dev/07-advanced-topics/multi-policy-training/) at once on one or many GPUs
# - Population-Based Training ([PBT](https://www.samplefactory.dev/07-advanced-topics/pbt/))
# - Discrete, continuous, hybrid action spaces
# - Vector-based, image-based, dictionary observation spaces
# - Automatically creates a model architecture by parsing action/observation space specification. Supports [custom model architectures](https://www.samplefactory.dev/03-customization/custom-models/)
# - Designed to be imported into other projects, [custom environments](https://www.samplefactory.dev/03-customization/custom-environments/) are first-class citizens
# - Detailed [WandB and Tensorboard summaries](https://www.samplefactory.dev/05-monitoring/metrics-reference/), [custom metrics](https://www.samplefactory.dev/05-monitoring/custom-metrics/)
# - [HuggingFace 🤗 integration](https://www.samplefactory.dev/10-huggingface/huggingface/) (upload trained models and metrics to the Hub)
# - [Multiple](https://www.samplefactory.dev/09-environment-integrations/mujoco/) [example](https://www.samplefactory.dev/09-environment-integrations/atari/) [environment](https://www.samplefactory.dev/09-environment-integrations/vizdoom/) [integrations](https://www.samplefactory.dev/09-environment-integrations/dmlab/) with tuned parameters and trained models
#
# All of the above policies are available on the 🤗 hub. Search for the tag [sample-factory](https://huggingface.co/models?library=sample-factory&sort=downloads)
#
# ### How sample-factory works
#
# Sample-factory is one of the **most highly optimized RL implementations available to the community**.
#
# It works by **spawning multiple processes that run rollout workers, inference workers and a learner worker**.
#
# The *workers* **communicate through shared memory, which lowers the communication cost between processes**.
#
# The *rollout workers* interact with the environment and send observations to the *inference workers*.
#
# The *inferences workers* query a fixed version of the policy and **send actions back to the rollout worker**.
#
# After *k* steps the rollout works send a trajectory of experience to the learner worker, **which it uses to update the agent’s policy network**.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/samplefactory.png" alt="Sample factory"/>

# %% [markdown]
# ### Actor Critic models in Sample-factory
#
# Actor Critic models in Sample Factory are composed of three components:
#
# - **Encoder** - Process input observations (images, vectors) and map them to a vector. This is the part of the model you will most likely want to customize.
# - **Core** - Intergrate vectors from one or more encoders, can optionally include a single- or multi-layer LSTM/GRU in a memory-based agent.
# - **Decoder** - Apply additional layers to the output of the model core before computing the policy and value outputs.
#
# The library has been designed to automatically support any observation and action spaces. Users can easily add their custom models. You can find out more in the [documentation](https://www.samplefactory.dev/03-customization/custom-models/#actor-critic-models-in-sample-factory).

# %% [markdown]
# ## ViZDoom
#
# [ViZDoom](https://vizdoom.cs.put.edu.pl/) is an **open-source python interface for the Doom Engine**.
#
# The library was created in 2016 by Marek Wydmuch, Michal Kempka  at the Institute of Computing Science, Poznan University of Technology, Poland.
#
# The library enables the **training of agents directly from the screen pixels in a number of scenarios**, including team deathmatch, shown in the video below. Because the ViZDoom environment is based on a game the was created in the 90s, it can be run on modern hardware at accelerated speeds, **allowing us to learn complex AI behaviors fairly quickly**.
#
# The library includes feature such as:
#
# - Multi-platform (Linux, macOS, Windows),
# - API for Python and C++,
# - [OpenAI Gym](https://www.gymlibrary.dev/) environment wrappers
# - Easy-to-create custom scenarios (visual editors, scripting language, and examples available),
# - Async and sync single-player and multiplayer modes,
# - Lightweight (few MBs) and fast (up to 7000 fps in sync mode, single-threaded),
# - Customizable resolution and rendering parameters,
# - Access to the depth buffer (3D vision),
# - Automatic labeling of game objects visible in the frame,
# - Access to the audio buffer
# - Access to the list of actors/objects and map geometry,
# - Off-screen rendering and episode recording,
# - Time scaling in async mode.

# %% [markdown]
# ## We first need to install some dependencies that are required for the ViZDoom environment
#
# Now that our Colab runtime is set up, we can start by installing the dependencies required to run ViZDoom on linux.
#
# If you are following on your machine on Mac, you will want to follow the installation instructions on the [github page](https://github.com/Farama-Foundation/ViZDoom/blob/master/doc/Quickstart.md#-quickstart-for-macos-and-anaconda3-python-36).

# %%
# %%capture
# %%bash
# Install ViZDoom deps from 
# https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md#-linux

apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev \
nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev \
libopenal-dev timidity libwildmidi-dev unzip ffmpeg

# Boost libraries
apt-get install libboost-all-dev

# Lua binding dependencies
apt-get install liblua5.1-dev

# %% [markdown]
# ## Then we can install Sample Factory and ViZDoom
# - This can take 7min

# %%
# install python libraries
# thanks toinsson
# !pip install sample-factory==2.0.2
# !pip install faster-fifo==1.4.2
# !pip install vizdoom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sample-factory==2.0.2
#   Downloading sample_factory-2.0.2-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.1<2.0 in /usr/local/lib/python3.10/dist-packages (from sample-factory==2.0.2) (1.22.4)
# Collecting torch<2.0,>=1.9 (from sample-factory==2.0.2)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.1 MB/s eta 0:00:00
# Collecting gym<1.0,>=0.26.1 (from sample-factory==2.0.2)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 62.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyglet (from sample-factory==2.0.2)
#   Downloading pyglet-2.0.7-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.0/841.0 kB 64.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from sample-factory==2.0.2) (2.12.2)
# Collecting tensorboardx>=2.0 (from sample-factory==2.0.2)
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from sample-factory==2.0.2) (5.9.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sample-factory==2.0.2) (3.1.0)
# Collecting colorlog (from sample-factory==2.0.2)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting faster-fifo<2.0,>=1.4.2 (from sample-factory==2.0.2)
#   Downloading faster-fifo-1.4.5.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 12.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting signal-slot-mp<2.0,>=1.0.3 (from sample-factory==2.0.2)
#   Downloading signal_slot_mp-1.0.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from sample-factory==2.0.2) (3.12.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from sample-factory==2.0.2) (4.7.0.72)
# Collecting wandb>=0.12.9 (from sample-factory==2.0.2)
#   Downloading wandb-0.15.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 93.1 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.10.0 (from sample-factory==2.0.2)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=45.2.0 in /usr/local/lib/python3.10/dist-packages (from faster-fifo<2.0,>=1.4.2->sample-factory==2.0.2) (67.7.2)
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.10/dist-packages (from faster-fifo<2.0,>=1.4.2->sample-factory==2.0.2) (0.29.34)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym<1.0,>=0.26.1->sample-factory==2.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<1.0,>=0.26.1->sample-factory==2.0.2) (0.0.8)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (23.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15.0->sample-factory==2.0.2) (0.40.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2.0,>=1.9->sample-factory==2.0.2)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 68.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2.0,>=1.9->sample-factory==2.0.2)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2.0,>=1.9->sample-factory==2.0.2)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2.0,>=1.9->sample-factory==2.0.2)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 78.9 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.12.9->sample-factory==2.0.2) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 27.4 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading sentry_sdk-1.24.0-py2.py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 24.5 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.12.9->sample-factory==2.0.2) (1.4.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.12.9->sample-factory==2.0.2) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15.0->sample-factory==2.0.2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15.0->sample-factory==2.0.2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15.0->sample-factory==2.0.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15.0->sample-factory==2.0.2) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.0.2) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.15.0->sample-factory==2.0.2) (2.1.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.12.9->sample-factory==2.0.2)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.15.0->sample-factory==2.0.2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15.0->sample-factory==2.0.2) (3.2.2)
# Building wheels for collected packages: faster-fifo, gym, pathtools
#   Building wheel for faster-fifo (pyproject.toml) ... done
#   Created wheel for faster-fifo: filename=faster_fifo-1.4.5-cp310-cp310-linux_x86_64.whl size=349949 sha256=0e34cea2698f961d4397123a357a5d644bd7672c4ad53b39111abd7be2bb37d6
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/46/342bb3a7b6352f83d926d2bfe8a932855b38f521b28f1da578
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827632 sha256=8e195c8d0ec7a9369f7f7d483395f172a868480b7a406bd84b29f73da70e6b4a
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=94597f371eef2cb445c4ffce8be3e70e5d7752a717e13eac862e2e59e4b84ab9
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built faster-fifo gym pathtools
# Installing collected packages: pyglet, pathtools, tensorboardx, smmap, setproctitle, sentry-sdk, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, gym, faster-fifo, docker-pycreds, colorlog, signal-slot-mp, nvidia-cudnn-cu11, huggingface-hub, gitdb, torch, GitPython, wandb, sample-factory
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.0.6 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed GitPython-3.1.31 colorlog-6.7.0 docker-pycreds-0.4.0 faster-fifo-1.4.5 gitdb-4.0.10 gym-0.26.2 huggingface-hub-0.14.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 pathtools-0.1.2 pyglet-2.0.7 sample-factory-2.0.2 sentry-sdk-1.24.0 setproctitle-1.3.2 signal-slot-mp-1.0.3 smmap-5.0.0 tensorboardx-2.6 torch-1.13.1 wandb-0.15.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faster-fifo==1.4.2
#   Downloading faster-fifo-1.4.2.tar.gz (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 10.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=45.2.0 in /usr/local/lib/python3.10/dist-packages (from faster-fifo==1.4.2) (67.7.2)
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.10/dist-packages (from faster-fifo==1.4.2) (0.29.34)
# Building wheels for collected packages: faster-fifo
#   Building wheel for faster-fifo (pyproject.toml) ... done
#   Created wheel for faster-fifo: filename=faster_fifo-1.4.2-cp310-cp310-linux_x86_64.whl size=339661 sha256=db84ab242cbf891d4bc8ac72e80175d03879685f0f03bcc4517476368ce7b676
#   Stored in directory: /root/.cache/pip/wheels/e9/72/37/2c9091826a1ceb1e7ece278f0e074e80be349a05fdb0a53d0d
# Successfully built faster-fifo
# Installing collected packages: faster-fifo
#   Attempting uninstall: faster-fifo
#     Found existing installation: faster-fifo 1.4.5
#     Uninstalling faster-fifo-1.4.5:
#       Successfully uninstalled faster-fifo-1.4.5
# Successfully installed faster-fifo-1.4.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vizdoom
#   Downloading vizdoom-1.2.0.tar.gz (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 79.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vizdoom) (1.22.4)
# Collecting gymnasium>=0.28.0 (from vizdoom)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from vizdoom) (2.3.0)
# Collecting jax-jumpy>=1.0.0 (from gymnasium>=0.28.0->vizdoom)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->vizdoom) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->vizdoom) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.28.0->vizdoom)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: vizdoom
#   Building wheel for vizdoom (pyproject.toml) ... done
#   Created wheel for vizdoom: filename=vizdoom-1.2.0-cp310-cp310-linux_x86_64.whl size=14295969 sha256=5acf227b2548f14a62bd98411f9354d159cfb4298b72808632de2221b7855ede
#   Stored in directory: /root/.cache/pip/wheels/89/6b/8c/5539439c888350cfe7098fea10d972336cb9f0c0c132ff0073
# Successfully built vizdoom
# Installing collected packages: farama-notifications, jax-jumpy, gymnasium, vizdoom
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 vizdoom-1.2.0

# %% [markdown]
# ## Setting up the Doom Environment in sample-factory

# %%
import functools

from sample_factory.algo.utils.context import global_model_factory
from sample_factory.cfg.arguments import parse_full_cfg, parse_sf_args
from sample_factory.envs.env_utils import register_env
from sample_factory.train import run_rl

from sf_examples.vizdoom.doom.doom_model import make_vizdoom_encoder
from sf_examples.vizdoom.doom.doom_params import add_doom_env_args, doom_override_defaults
from sf_examples.vizdoom.doom.doom_utils import DOOM_ENVS, make_doom_env_from_spec


# Registers all the ViZDoom environments
def register_vizdoom_envs():
    for env_spec in DOOM_ENVS:
        make_env_func = functools.partial(make_doom_env_from_spec, env_spec)
        register_env(env_spec.name, make_env_func)

# Sample Factory allows the registration of a custom Neural Network architecture
# See https://github.com/alex-petrenko/sample-factory/blob/master/sf_examples/vizdoom/doom/doom_model.py for more details
def register_vizdoom_models():
    global_model_factory().register_encoder_factory(make_vizdoom_encoder)


def register_vizdoom_components():
    register_vizdoom_envs()
    register_vizdoom_models()

# parse the command line args and create a config
def parse_vizdoom_cfg(argv=None, evaluation=False):
    parser, _ = parse_sf_args(argv=argv, evaluation=evaluation)
    # parameters specific to Doom envs
    add_doom_env_args(parser)
    # override Doom default values for algo parameters
    doom_override_defaults(parser)
    # second parsing pass yields the final configuration
    final_cfg = parse_full_cfg(parser, argv)
    return final_cfg

# %% [markdown]
# Now that the setup if complete, we can train the agent. We have chosen here to learn a ViZDoom task called `Health Gathering Supreme`.
#
# ### The scenario: Health Gathering Supreme
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/Health-Gathering-Supreme.png" alt="Health-Gathering-Supreme"/>
#
#
#
# The objective of this scenario is to **teach the agent how to survive without knowing what makes him survive**. Agent know only that **life is precious** and death is bad so **it must learn what prolongs his existence and that his health is connected with it**.
#
# Map is a rectangle containing walls and with a green, acidic floor which **hurts the player periodically**. Initially there are some medkits spread uniformly over the map. A new medkit falls from the skies every now and then. **Medkits heal some portions of player's health** - to survive agent needs to pick them up. Episode finishes after player's death or on timeout.
#
# Further configuration:
# - Living_reward = 1
# - 3 available buttons: turn left, turn right, move forward
# - 1 available game variable: HEALTH
# - death penalty = 100
#
# You can find out more about the scenarios available in ViZDoom [here](https://github.com/Farama-Foundation/ViZDoom/tree/master/scenarios).
#
# There are also a number of more complex scenarios that have been create for ViZDoom, such as the ones detailed on [this github page](https://github.com/edbeeching/3d_control_deep_rl).

# %% [markdown]
# ## Training the agent
# - We're going to train the agent for 4000000 steps it will take approximately 20min

# %%
## Start the training, this should take around 15 minutes
register_vizdoom_components()

# The scenario we train on today is health gathering
# other scenarios include "doom_basic", "doom_two_colors_easy", "doom_dm", "doom_dwango5", "doom_my_way_home", "doom_deadly_corridor", "doom_defend_the_center", "doom_defend_the_line"
env = "doom_health_gathering_supreme"
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=8", "--num_envs_per_worker=4", "--train_for_env_steps=5000000"])

status = run_rl(cfg)
# Out:
# [2023-05-26 04:04:27,191][00299] register_encoder_factory: <function make_vizdoom_encoder at 0x7f2c69341480>
# [2023-05-26 04:04:27,207][00299] Saved parameter configuration for experiment default_experiment not found!
# [2023-05-26 04:04:27,209][00299] Starting experiment from scratch!
# [2023-05-26 04:04:27,219][00299] Experiment dir /content/train_dir/default_experiment already exists!
# [2023-05-26 04:04:27,220][00299] Resuming existing experiment from /content/train_dir/default_experiment...
# [2023-05-26 04:04:27,222][00299] Weights and Biases integration disabled
# [2023-05-26 04:04:28,913][00299] Queried available GPUs: 0
#
# [2023-05-26 04:04:28,915][00299] Environment var CUDA_VISIBLE_DEVICES is 0
#
# [2023-05-26 04:04:30,432][00299] Starting experiment with the following configuration:
# help=False
# algo=APPO
# env=doom_health_gathering_supreme
# experiment=default_experiment
# train_dir=/content/train_dir
# restart_behavior=resume
# device=gpu
# seed=None
# num_policies=1
# async_rl=True
# serial_mode=False
# batched_sampling=False
# num_batches_to_accumulate=2
# worker_num_splits=2
# policy_workers_per_policy=1
# max_policy_lag=1000
# num_workers=8
# num_envs_per_worker=4
# batch_size=1024
# num_batches_per_epoch=1
# num_epochs=1
# rollout=32
# recurrence=32
# shuffle_minibatches=False
# gamma=0.99
# reward_scale=1.0
# reward_clip=1000.0
# value_bootstrap=False
# normalize_returns=True
# exploration_loss_coeff=0.001
# value_loss_coeff=0.5
# kl_loss_coeff=0.0
# exploration_loss=symmetric_kl
# gae_lambda=0.95
# ppo_clip_ratio=0.1
# ppo_clip_value=0.2
# with_vtrace=False
# vtrace_rho=1.0
# vtrace_c=1.0
# optimizer=adam
# adam_eps=1e-06
# adam_beta1=0.9
# adam_beta2=0.999
# max_grad_norm=4.0
# learning_rate=0.0001
# lr_schedule=constant
# lr_schedule_kl_threshold=0.008
# obs_subtract_mean=0.0
# obs_scale=255.0
# normalize_input=True
# normalize_input_keys=None
# decorrelate_experience_max_seconds=0
# decorrelate_envs_on_one_worker=True
# actor_worker_gpus=[]
# set_workers_cpu_affinity=True
# force_envs_single_thread=False
# default_niceness=0
# log_to_file=True
# experiment_summaries_interval=10
# flush_summaries_interval=30
# stats_avg=100
# summaries_use_frameskip=True
# heartbeat_interval=20
# heartbeat_reporting_interval=600
# train_for_env_steps=5000000
# train_for_seconds=10000000000
# save_every_sec=120
# keep_checkpoints=2
# load_checkpoint_kind=latest
# save_milestones_sec=-1
# save_best_every_sec=5
# save_best_metric=reward
# save_best_after=100000
# benchmark=False
# encoder_mlp_layers=[512, 512]
# encoder_conv_architecture=convnet_simple
# encoder_conv_mlp_layers=[512]
# use_rnn=True
# rnn_size=512
# rnn_type=gru
# rnn_num_layers=1
# decoder_mlp_layers=[]
# nonlinearity=elu
# policy_initialization=orthogonal
# policy_init_gain=1.0
# actor_critic_share_weights=True
# adaptive_stddev=True
# continuous_tanh_scale=0.0
# initial_stddev=1.0
# use_env_info_cache=False
# env_gpu_actions=False
# env_gpu_observations=True
# env_frameskip=4
# env_framestack=1
# pixel_format=CHW
# use_record_episode_statistics=False
# with_wandb=False
# wandb_user=None
# wandb_project=sample_factory
# wandb_group=None
# wandb_job_type=SF
# wandb_tags=[]
# with_pbt=False
# pbt_mix_policies_in_one_env=True
# pbt_period_env_steps=5000000
# pbt_start_mutation=20000000
# pbt_replace_fraction=0.3
# pbt_mutation_rate=0.15
# pbt_replace_reward_gap=0.1
# pbt_replace_reward_gap_absolute=1e-06
# pbt_optimize_gamma=False
# pbt_target_objective=true_objective
# pbt_perturb_min=1.1
# pbt_perturb_max=1.5
# num_agents=-1
# num_humans=0
# num_bots=-1
# start_bot_difficulty=None
# timelimit=None
# res_w=128
# res_h=72
# wide_aspect_ratio=False
# eval_env_frameskip=1
# fps=35
# command_line=--env=doom_health_gathering_supreme --num_workers=8 --num_envs_per_worker=4 --train_for_env_steps=5000000
# cli_args={'env': 'doom_health_gathering_supreme', 'num_workers': 8, 'num_envs_per_worker': 4, 'train_for_env_steps': 5000000}
# git_hash=unknown
# git_repo_name=not a git repository
# train_script=.usr.local.lib.python3.10.dist-packages.ipykernel_launcher
# [2023-05-26 04:04:30,433][00299] Saving configuration to /content/train_dir/default_experiment/config.json...
# [2023-05-26 04:04:30,438][00299] Rollout worker 0 uses device cpu
# [2023-05-26 04:04:30,440][00299] Rollout worker 1 uses device cpu
# [2023-05-26 04:04:30,442][00299] Rollout worker 2 uses device cpu
# [2023-05-26 04:04:30,445][00299] Rollout worker 3 uses device cpu
# [2023-05-26 04:04:30,448][00299] Rollout worker 4 uses device cpu
# [2023-05-26 04:04:30,450][00299] Rollout worker 5 uses device cpu
# [2023-05-26 04:04:30,453][00299] Rollout worker 6 uses device cpu
# [2023-05-26 04:04:30,458][00299] Rollout worker 7 uses device cpu
# [2023-05-26 04:04:30,596][00299] Using GPUs [0] for process 0 (actually maps to GPUs [0])
# [2023-05-26 04:04:30,598][00299] InferenceWorker_p0-w0: min num requests: 2
# [2023-05-26 04:04:30,629][00299] Starting all processes...
# [2023-05-26 04:04:30,631][00299] Starting process learner_proc0
# [2023-05-26 04:04:30,679][00299] Starting all processes...
# [2023-05-26 04:04:30,692][00299] Starting process inference_proc0-0
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc0
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc1
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc2
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc3
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc4
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc5
# [2023-05-26 04:04:30,693][00299] Starting process rollout_proc6
# [2023-05-26 04:30:39,680][00299] Waiting for process rollout_proc1 to join...
# [2023-05-26 04:30:39,682][00299] Waiting for process rollout_proc2 to join...
# [2023-05-26 04:30:39,684][00299] Waiting for process rollout_proc3 to join...
# [2023-05-26 04:30:39,685][00299] Waiting for process rollout_proc4 to join...
# [2023-05-26 04:30:39,688][00299] Waiting for process rollout_proc5 to join...
# [2023-05-26 04:30:39,690][00299] Waiting for process rollout_proc6 to join...
# [2023-05-26 04:30:39,695][00299] Waiting for process rollout_proc7 to join...
# [2023-05-26 04:30:39,696][00299] Batcher 0 profile tree view:
# batching: 35.1934, releasing_batches: 0.0344
# [2023-05-26 04:30:39,697][00299] InferenceWorker_p0-w0 profile tree view:
# wait_policy: 0.0000
#   wait_policy_total: 689.3606
# update_model: 10.8863
#   weight_update: 0.0012
# one_step: 0.0041
#   handle_policy_step: 786.1917
#     deserialize: 20.6554, stack: 4.1115, obs_to_device_normalize: 160.7351, forward: 405.3990, send_messages: 39.2193
#     prepare_outputs: 117.4547
#       to_cpu: 72.1433
# [2023-05-26 04:30:39,699][00299] Learner 0 profile tree view:
# misc: 0.0104, prepare_batch: 20.2815
# train: 92.7591
#   epoch_init: 0.0146, minibatch_init: 0.0091, losses_postprocess: 0.6193, kl_divergence: 0.9040, after_optimizer: 38.5445
#   calculate_losses: 32.0377
#     losses_init: 0.0094, forward_head: 2.4916, bptt_initial: 19.7722, tail: 1.8052, advantages_returns: 0.4229, losses: 3.8647
#     bptt: 3.2597
#       bptt_forward_core: 3.1550
#   update: 19.5830
#     clip: 1.9733
# [2023-05-26 04:30:39,700][00299] RolloutWorker_w0 profile tree view:
# wait_for_trajectories: 0.4942, enqueue_policy_requests: 197.4555, env_step: 1153.6210, overhead: 34.8256, complete_rollouts: 9.7468
# save_policy_outputs: 32.1303
#   split_output_tensors: 15.6060
# [2023-05-26 04:30:39,707][00299] RolloutWorker_w7 profile tree view:
# wait_for_trajectories: 0.4877, enqueue_policy_requests: 203.1305, env_step: 1149.7711, overhead: 33.4953, complete_rollouts: 9.8955
# save_policy_outputs: 31.7290
#   split_output_tensors: 15.1844
# [2023-05-26 04:30:39,709][00299] Loop Runner_EvtLoop terminating...
# [2023-05-26 04:30:39,710][00299] Runner profile tree view:
# main_loop: 1569.0809
# [2023-05-26 04:30:39,711][00299] Collected {0: 5005312}, FPS: 3190.0

# %% [markdown]
# ## Let's take a look at the performance of the trained policy and output a video of the agent.

# %%
from sample_factory.enjoy import enjoy
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=10"], evaluation=True)
status = enjoy(cfg)
# Out:
# [2023-05-26 04:32:30,132][00299] Loading existing experiment configuration from /content/train_dir/default_experiment/config.json
# [2023-05-26 04:32:30,138][00299] Overriding arg 'num_workers' with value 1 passed from command line
# [2023-05-26 04:32:30,140][00299] Adding new argument 'no_render'=True that is not in the saved config file!
# [2023-05-26 04:32:30,141][00299] Adding new argument 'save_video'=True that is not in the saved config file!
# [2023-05-26 04:32:30,143][00299] Adding new argument 'video_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:32:30,145][00299] Adding new argument 'video_name'=None that is not in the saved config file!
# [2023-05-26 04:32:30,150][00299] Adding new argument 'max_num_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:32:30,152][00299] Adding new argument 'max_num_episodes'=10 that is not in the saved config file!
# [2023-05-26 04:32:30,153][00299] Adding new argument 'push_to_hub'=False that is not in the saved config file!
# [2023-05-26 04:32:30,154][00299] Adding new argument 'hf_repository'=None that is not in the saved config file!
# [2023-05-26 04:32:30,155][00299] Adding new argument 'policy_index'=0 that is not in the saved config file!
# [2023-05-26 04:32:30,156][00299] Adding new argument 'eval_deterministic'=False that is not in the saved config file!
# [2023-05-26 04:32:30,156][00299] Using frameskip 1 and render_action_repeat=4 for evaluation
# [2023-05-26 04:32:30,195][00299] Doom resolution: 160x120, resize resolution: (128, 72)
# [2023-05-26 04:32:30,199][00299] RunningMeanStd input shape: (3, 72, 128)
# [2023-05-26 04:32:30,202][00299] RunningMeanStd input shape: (1,)
# [2023-05-26 04:32:30,228][00299] ConvEncoder: input_channels=3
# [2023-05-26 04:32:30,433][00299] Conv encoder output size: 512
# [2023-05-26 04:32:30,435][00299] Policy head output size: 512
# [2023-05-26 04:32:33,484][00299] Loading state from checkpoint /content/train_dir/default_experiment/checkpoint_p0/checkpoint_000001222_5005312.pth...
# [2023-05-26 04:32:35,607][00299] Avg episode rewards: #0: 21.860, true rewards: #0: 8.860
# [2023-05-26 04:32:35,609][00299] Avg episode reward: 21.860, avg true_objective: 8.860
# [2023-05-26 04:32:36,364][00299] Avg episode rewards: #0: 16.270, true rewards: #0: 7.270
# [2023-05-26 04:32:36,366][00299] Avg episode reward: 16.270, avg true_objective: 7.270
# [2023-05-26 04:32:37,870][00299] Avg episode rewards: #0: 20.567, true rewards: #0: 8.900
# [2023-05-26 04:32:37,873][00299] Avg episode reward: 20.567, avg true_objective: 8.900
# [2023-05-26 04:32:39,780][00299] Avg episode rewards: #0: 23.095, true rewards: #0: 10.595
# [2023-05-26 04:32:39,781][00299] Avg episode reward: 23.095, avg true_objective: 10.595
# [2023-05-26 04:32:42,366][00299] Avg episode rewards: #0: 30.076, true rewards: #0: 12.676
# [2023-05-26 04:32:42,367][00299] Avg episode reward: 30.076, avg true_objective: 12.676
# [2023-05-26 04:32:44,424][00299] Avg episode rewards: #0: 30.363, true rewards: #0: 12.697
# [2023-05-26 04:32:44,427][00299] Avg episode reward: 30.363, avg true_objective: 12.697
# [2023-05-26 04:32:45,696][00299] Avg episode rewards: #0: 28.479, true rewards: #0: 11.907
# [2023-05-26 04:32:45,699][00299] Avg episode reward: 28.479, avg true_objective: 11.907
# [2023-05-26 04:32:46,905][00299] Avg episode rewards: #0: 26.871, true rewards: #0: 11.246
# [2023-05-26 04:32:46,907][00299] Avg episode reward: 26.871, avg true_objective: 11.246
# [2023-05-26 04:32:48,306][00299] Avg episode rewards: #0: 26.032, true rewards: #0: 10.921
# [2023-05-26 04:32:48,308][00299] Avg episode reward: 26.032, avg true_objective: 10.921
# [2023-05-26 04:32:48,916][00299] Avg episode rewards: #0: 24.145, true rewards: #0: 10.245
# [2023-05-26 04:32:48,917][00299] Avg episode reward: 24.145, avg true_objective: 10.245

# %% [markdown]
# ## Now lets visualize the performance of the agent

# %%
from base64 import b64encode
from IPython.display import HTML

mp4 = open('/content/train_dir/default_experiment/replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# The agent has learned something, but its performance could be better. We would clearly need to train for longer. But let's upload this model to the Hub.

# %% [markdown]
# ## Now lets upload your checkpoint and video to the Hugging Face Hub

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from sample_factory.enjoy import enjoy

hf_username = "QuickSilver007" # insert your HuggingFace username here

cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=10", "--max_num_frames=100000", "--push_to_hub", f"--hf_repository={hf_username}/rlv2unit8_vizdoom_health_gathering_supreme"], evaluation=True)
status = enjoy(cfg)
# Out:
# [2023-05-26 04:41:08,127][00299] Loading existing experiment configuration from /content/train_dir/default_experiment/config.json
# [2023-05-26 04:41:08,129][00299] Overriding arg 'num_workers' with value 1 passed from command line
# [2023-05-26 04:41:08,131][00299] Adding new argument 'no_render'=True that is not in the saved config file!
# [2023-05-26 04:41:08,133][00299] Adding new argument 'save_video'=True that is not in the saved config file!
# [2023-05-26 04:41:08,135][00299] Adding new argument 'video_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:41:08,140][00299] Adding new argument 'video_name'=None that is not in the saved config file!
# [2023-05-26 04:41:08,141][00299] Adding new argument 'max_num_frames'=100000 that is not in the saved config file!
# [2023-05-26 04:41:08,143][00299] Adding new argument 'max_num_episodes'=10 that is not in the saved config file!
# [2023-05-26 04:41:08,144][00299] Adding new argument 'push_to_hub'=True that is not in the saved config file!
# [2023-05-26 04:41:08,147][00299] Adding new argument 'hf_repository'='QuickSilver007/rlv2unit8_vizdoom_health_gathering_supreme' that is not in the saved config file!
# [2023-05-26 04:41:08,148][00299] Adding new argument 'policy_index'=0 that is not in the saved config file!
# [2023-05-26 04:41:08,149][00299] Adding new argument 'eval_deterministic'=False that is not in the saved config file!
# [2023-05-26 04:41:08,150][00299] Using frameskip 1 and render_action_repeat=4 for evaluation
# [2023-05-26 04:41:08,177][00299] RunningMeanStd input shape: (3, 72, 128)
# [2023-05-26 04:41:08,179][00299] RunningMeanStd input shape: (1,)
# [2023-05-26 04:41:08,200][00299] ConvEncoder: input_channels=3
# [2023-05-26 04:41:08,262][00299] Conv encoder output size: 512
# [2023-05-26 04:41:08,268][00299] Policy head output size: 512
# [2023-05-26 04:41:08,300][00299] Loading state from checkpoint /content/train_dir/default_experiment/checkpoint_p0/checkpoint_000001222_5005312.pth...
# [2023-05-26 04:41:10,640][00299] Avg episode rewards: #0: 23.560, true rewards: #0: 10.560
# [2023-05-26 04:41:10,642][00299] Avg episode reward: 23.560, avg true_objective: 10.560
# [2023-05-26 04:41:12,411][00299] Avg episode rewards: #0: 23.755, true rewards: #0: 10.255
# [2023-05-26 04:41:12,413][00299] Avg episode reward: 23.755, avg true_objective: 10.255
# [2023-05-26 04:41:15,271][00299] Avg episode rewards: #0: 35.836, true rewards: #0: 13.837
# [2023-05-26 04:41:15,273][00299] Avg episode reward: 35.836, avg true_objective: 13.837
# [2023-05-26 04:41:17,385][00299] Avg episode rewards: #0: 34.407, true rewards: #0: 13.657
# [2023-05-26 04:41:17,392][00299] Avg episode reward: 34.407, avg true_objective: 13.657
# [2023-05-26 04:41:18,508][00299] Avg episode rewards: #0: 29.742, true rewards: #0: 12.142
# [2023-05-26 04:41:18,510][00299] Avg episode reward: 29.742, avg true_objective: 12.142
# [2023-05-26 04:41:20,089][00299] Avg episode rewards: #0: 29.112, true rewards: #0: 11.612
# [2023-05-26 04:41:20,091][00299] Avg episode reward: 29.112, avg true_objective: 11.612
# [2023-05-26 04:41:21,247][00299] Avg episode rewards: #0: 26.530, true rewards: #0: 10.959
# [2023-05-26 04:41:21,248][00299] Avg episode reward: 26.530, avg true_objective: 10.959
# [2023-05-26 04:41:23,210][00299] Avg episode rewards: #0: 27.579, true rewards: #0: 11.579
# [2023-05-26 04:41:23,212][00299] Avg episode reward: 27.579, avg true_objective: 11.579
# [2023-05-26 04:41:24,643][00299] Avg episode rewards: #0: 27.584, true rewards: #0: 11.584
# [2023-05-26 04:41:24,646][00299] Avg episode reward: 27.584, avg true_objective: 11.584
# [2023-05-26 04:41:26,713][00299] Avg episode rewards: #0: 29.192, true rewards: #0: 12.092
# [2023-05-26 04:41:26,716][00299] Avg episode reward: 29.192, avg true_objective: 12.092
# events.out.tfevents.1685073867.185de0f86aa9:   0%|          | 0.00/663k [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# best_000001149_4706304_reward_29.351.pth:   0%|          | 0.00/34.9M [00:00<?, ?B/s]
# checkpoint_000001213_4968448.pth:   0%|          | 0.00/34.9M [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# checkpoint_000001222_5005312.pth:   0%|          | 0.00/34.9M [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# replay.mp4:   0%|          | 0.00/23.1M [00:00<?, ?B/s]
# [2023-05-26 04:43:08,691][00299] The model has been pushed to https://huggingface.co/QuickSilver007/rlv2unit8_vizdoom_health_gathering_supreme

# %% [markdown]
# ## Let's load another model

# %% [markdown]
# This agent's performance was good, but can do better! Let's download and visualize an agent trained for 10B timesteps from the hub.

# %%
#download the agent from the hub
# !python -m sample_factory.huggingface.load_from_hub -r edbeeching/doom_health_gathering_supreme_2222 -d ./train_dir
# Out:
# Cloning https://huggingface.co/edbeeching/doom_health_gathering_supreme_2222 into local empty directory.
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  21% 8.24M/39.3M [00:01<00:03, 8.61MB/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth:   0% 32.0k/39.3M [00:00<?, ?B/s]
#
# Download file .summary/0/events.out.tfevents.1666554178.r12i0n7:   0% 32.0k/8.77M [00:00<?, ?B/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth:   0% 32.0k/39.3M [00:00<?, ?B/s]
#
#
#
# Download file replay.mp4:   1% 32.0k/4.07M [00:00<?, ?B/s]
#
#
#
#
# Clean file replay.mp4:   0% 1.00k/4.07M [00:00<?, ?B/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth:  13% 5.03M/39.3M [00:01<00:06, 5.21MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth:  13% 5.00M/39.3M [00:01<00:06, 5.18MB/s]
#
#
#
#
# Clean file replay.mp4:  17% 705k/4.07M [00:01<00:04, 719kB/s]
#
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  34% 13.4M/39.3M [00:02<00:04, 6.68MB/s]
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554178.r12i0n7:   0% 1.00k/8.77M [00:00<?, ?B/s]
#
#
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  48% 18.7M/39.3M [00:03<00:03, 6.19MB/s]
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554178.r12i0n7:  17% 1.47M/8.77M [00:01<00:04, 1.54MB/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth:  27% 10.5M/39.3M [00:02<00:05, 5.48MB/s]
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554178.r12i0n7:  79% 6.91M/8.77M [00:02<00:00, 3.98MB/s]
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  62% 24.2M/39.3M [00:04<00:02, 6.02MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth:  40% 15.9M/39.3M [00:03<00:04, 5.58MB/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth:  51% 20.0M/39.3M [00:04<00:03, 5.07MB/s]
#
#
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  85% 33.5M/39.3M [00:06<00:01, 5.39MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth:  64% 25.1M/39.3M [00:05<00:02, 5.18MB/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth:  64% 25.2M/39.3M [00:05<00:02, 5.18MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth:  78% 30.7M/39.3M [00:06<00:01, 5.39MB/s]
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  99% 39.1M/39.3M [00:07<00:00, 5.53MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:   0% 1.00k/39.3M [00:00<?, ?B/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth:  88% 34.6M/39.3M [00:07<00:01, 4.94MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth:  88% 34.5M/39.3M [00:07<00:01, 4.94MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:   9% 3.38M/39.3M [00:01<00:10, 3.53MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  22% 8.53M/39.3M [00:02<00:06, 4.62MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  38% 15.0M/39.3M [00:03<00:04, 5.59MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  62% 24.3M/39.3M [00:04<00:02, 7.23MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth:  86% 33.9M/39.3M [00:05<00:00, 8.25MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth:   0% 1.00k/39.3M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth:  12% 4.66M/39.3M [00:01<00:07, 4.87MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth:  38% 14.9M/39.3M [00:02<00:03, 8.30MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth:  62% 24.6M/39.3M [00:03<00:01, 9.14MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth:  88% 34.5M/39.3M [00:04<00:00, 9.62MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000538763_4413546496.pth:   0% 1.00k/39.3M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000538763_4413546496.pth:  13% 5.03M/39.3M [00:01<00:06, 5.27MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000538763_4413546496.pth:  36% 14.1M/39.3M [00:02<00:03, 7.73MB/s]
#
#
#
#
#
#
#
#
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth: 100% 39.3M/39.3M [00:19<00:00, 5.53MB/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth: 100% 39.3M/39.3M [00:18<00:00, 4.94MB/s]
#
#
#
#
# Clean file replay.mp4: 100% 4.07M/4.07M [00:18<00:00, 719kB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth: 100% 39.3M/39.3M [00:18<00:00, 4.94MB/s]
#
# Download file .summary/0/events.out.tfevents.1666554178.r12i0n7: 100% 8.77M/8.77M [00:18<00:00, 5.15MB/s]
#
#
#
#
#
# Download file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth: 100% 39.3M/39.3M [00:20<00:00, 2.05MB/s]
#
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth: 100% 39.3M/39.3M [00:19<00:00, 1.10MB/s]
# Download file checkpoint_p0/checkpoint_000539850_4422451200.pth: 100% 39.3M/39.3M [00:19<00:00, 2.16MB/s]
#
#
# Download file .summary/0/events.out.tfevents.1666554178.r12i0n7: 100% 8.77M/8.77M [00:19<00:00, 406kB/s]
#
# Download file .summary/0/events.out.tfevents.1666554178.r12i0n7: 100% 8.77M/8.77M [00:19<00:00, 481kB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth: 100% 39.3M/39.3M [00:19<00:00, 1.10MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000538763_4413546496.pth: 100% 39.3M/39.3M [00:19<00:00, 2.16MB/s]
#
#
#
#
# Download file replay.mp4: 100% 4.07M/4.07M [00:19<00:00, 222kB/s]
#
#
#
# Download file replay.mp4: 100% 4.07M/4.07M [00:19<00:00, 222kB/s]
#
#
#
#
#
# Clean file replay.mp4: 100% 4.07M/4.07M [00:19<00:00, 216kB/s]
#
#
#
#
# Clean file replay.mp4: 100% 4.07M/4.07M [00:19<00:00, 224kB/s]
#
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554178.r12i0n7: 100% 8.77M/8.77M [00:18<00:00, 388kB/s]
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554178.r12i0n7: 100% 8.77M/8.77M [00:18<00:00, 509kB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth: 100% 39.3M/39.3M [00:13<00:00, 2.18MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000466273_3819708416_reward_63.056.pth: 100% 39.3M/39.3M [00:13<00:00, 3.16MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth: 100% 39.3M/39.3M [00:08<00:00, 3.83MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000539850_4422451200.pth: 100% 39.3M/39.3M [00:08<00:00, 5.14MB/s]
#
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000538763_4413546496.pth: 100% 39.3M/39.3M [00:04<00:00, 11.8MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000538763_4413546496.pth: 100% 39.3M/39.3M [00:04<00:00, 10.3MB/s]
# [2023-05-26 04:48:48,552][27668] The repository edbeeching/doom_health_gathering_supreme_2222 has been cloned to ./train_dir/doom_health_gathering_supreme_2222

# %%
# !ls train_dir/doom_health_gathering_supreme_2222
# Out:
# cfg.json  checkpoint_p0  README.md  replay.mp4

# %%
env = "doom_health_gathering_supreme"
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=10", "--experiment=doom_health_gathering_supreme_2222", "--train_dir=train_dir"], evaluation=True)
status = enjoy(cfg)
# Out:
# [2023-05-26 04:48:52,668][00299] Loading legacy config file train_dir/doom_health_gathering_supreme_2222/cfg.json instead of train_dir/doom_health_gathering_supreme_2222/config.json
# [2023-05-26 04:48:52,670][00299] Loading existing experiment configuration from train_dir/doom_health_gathering_supreme_2222/config.json
# [2023-05-26 04:48:52,674][00299] Overriding arg 'experiment' with value 'doom_health_gathering_supreme_2222' passed from command line
# [2023-05-26 04:48:52,677][00299] Overriding arg 'train_dir' with value 'train_dir' passed from command line
# [2023-05-26 04:48:52,681][00299] Overriding arg 'num_workers' with value 1 passed from command line
# [2023-05-26 04:48:52,682][00299] Adding new argument 'env_gpu_observations'=True that is not in the saved config file!
# [2023-05-26 04:48:52,683][00299] Adding new argument 'no_render'=True that is not in the saved config file!
# [2023-05-26 04:48:52,686][00299] Adding new argument 'save_video'=True that is not in the saved config file!
# [2023-05-26 04:48:52,688][00299] Adding new argument 'video_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:48:52,689][00299] Adding new argument 'video_name'=None that is not in the saved config file!
# [2023-05-26 04:48:52,690][00299] Adding new argument 'max_num_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:48:52,692][00299] Adding new argument 'max_num_episodes'=10 that is not in the saved config file!
# [2023-05-26 04:48:52,695][00299] Adding new argument 'push_to_hub'=False that is not in the saved config file!
# [2023-05-26 04:48:52,696][00299] Adding new argument 'hf_repository'=None that is not in the saved config file!
# [2023-05-26 04:48:52,697][00299] Adding new argument 'policy_index'=0 that is not in the saved config file!
# [2023-05-26 04:48:52,698][00299] Adding new argument 'eval_deterministic'=False that is not in the saved config file!
# [2023-05-26 04:48:52,699][00299] Adding new argument 'train_script'='.usr.local.lib.python3.10.dist-packages.ipykernel_launcher' that is not in the saved config file!
# [2023-05-26 04:48:52,702][00299] Using frameskip 1 and render_action_repeat=4 for evaluation
# [2023-05-26 04:48:52,732][00299] RunningMeanStd input shape: (3, 72, 128)
# [2023-05-26 04:48:52,736][00299] RunningMeanStd input shape: (1,)
# [2023-05-26 04:48:52,759][00299] ConvEncoder: input_channels=3
# [2023-05-26 04:48:52,832][00299] Conv encoder output size: 512
# [2023-05-26 04:48:52,836][00299] Policy head output size: 512
# [2023-05-26 04:48:52,873][00299] Loading state from checkpoint train_dir/doom_health_gathering_supreme_2222/checkpoint_p0/checkpoint_000539850_4422451200.pth...
# [2023-05-26 04:48:56,745][00299] Avg episode rewards: #0: 62.998, true rewards: #0: 21.000
# [2023-05-26 04:48:56,747][00299] Avg episode reward: 62.998, avg true_objective: 21.000
# [2023-05-26 04:48:57,787][00299] Avg episode rewards: #0: 42.009, true rewards: #0: 14.510
# [2023-05-26 04:48:57,790][00299] Avg episode reward: 42.009, avg true_objective: 14.510
# [2023-05-26 04:49:00,443][00299] Avg episode rewards: #0: 49.339, true rewards: #0: 16.673
# [2023-05-26 04:49:00,445][00299] Avg episode reward: 49.339, avg true_objective: 16.673
# [2023-05-26 04:49:02,906][00299] Avg episode rewards: #0: 50.884, true rewards: #0: 17.385
# [2023-05-26 04:49:02,908][00299] Avg episode reward: 50.884, avg true_objective: 17.385
# [2023-05-26 04:49:05,606][00299] Avg episode rewards: #0: 53.307, true rewards: #0: 18.108
# [2023-05-26 04:49:05,609][00299] Avg episode reward: 53.307, avg true_objective: 18.108
# [2023-05-26 04:49:10,835][00299] Avg episode rewards: #0: 50.126, true rewards: #0: 17.293
# [2023-05-26 04:49:10,837][00299] Avg episode reward: 50.126, avg true_objective: 17.293
# [2023-05-26 04:49:13,979][00299] Avg episode rewards: #0: 52.250, true rewards: #0: 17.823
# [2023-05-26 04:49:13,981][00299] Avg episode reward: 52.250, avg true_objective: 17.823
# [2023-05-26 04:49:16,728][00299] Avg episode rewards: #0: 53.344, true rewards: #0: 18.220
# [2023-05-26 04:49:16,729][00299] Avg episode reward: 53.344, avg true_objective: 18.220
# [2023-05-26 04:49:18,731][00299] Avg episode rewards: #0: 52.492, true rewards: #0: 17.938
# [2023-05-26 04:49:18,732][00299] Avg episode reward: 52.492, avg true_objective: 17.938
# [2023-05-26 04:49:21,370][00299] Avg episode rewards: #0: 53.643, true rewards: #0: 18.244
# [2023-05-26 04:49:21,372][00299] Avg episode reward: 53.643, avg true_objective: 18.244

# %%
mp4 = open('/content/train_dir/doom_health_gathering_supreme_2222/replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# ## Some additional challenges 🏆: Doom Deathmatch
#
# Training an agent to play a Doom deathmatch **takes many hours on a more beefy machine than is available in Colab**.
#
# Fortunately, we have have **already trained an agent in this scenario and it is available in the 🤗 Hub!** Let’s download the model and visualize the agent’s performance.

# %%
# Download the agent from the hub
# !python -m sample_factory.huggingface.load_from_hub -r edbeeching/doom_deathmatch_bots_2222 -d ./train_dir
# Out:
# Cloning https://huggingface.co/edbeeching/doom_deathmatch_bots_2222 into local empty directory.
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:   9% 3.75M/39.5M [00:01<00:09, 3.89MB/s]
# Download file replay.mp4:   0% 32.0k/6.94M [00:00<?, ?B/s]
#
# Download file .summary/0/events.out.tfevents.1666554187.r13i1n3:   0% 24.0k/9.32M [00:00<?, ?B/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:   0% 32.0k/39.5M [00:00<?, ?B/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:   0% 32.0k/39.5M [00:00<?, ?B/s]
#
# Download file .summary/0/events.out.tfevents.1666554187.r13i1n3:  26% 2.43M/9.32M [00:01<00:02, 2.52MB/s]
# Download file replay.mp4:  37% 2.56M/6.94M [00:01<00:01, 2.65MB/s]
#
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  29% 11.6M/39.5M [00:02<00:04, 6.40MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:   6% 2.41M/39.5M [00:01<00:15, 2.48MB/s]
#
#
#
#
# Clean file replay.mp4:   0% 1.00k/6.94M [00:00<?, ?B/s]
#
#
#
#
# Clean file replay.mp4:  12% 865k/6.94M [00:01<00:07, 883kB/s]
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  43% 17.0M/39.5M [00:03<00:03, 6.05MB/s]
#
# Download file .summary/0/events.out.tfevents.1666554187.r13i1n3:  84% 7.84M/9.32M [00:02<00:00, 4.35MB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:  20% 7.78M/39.5M [00:02<00:07, 4.33MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:  33% 13.2M/39.5M [00:03<00:05, 4.93MB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:  34% 13.2M/39.5M [00:03<00:05, 4.96MB/s]
#
#
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  57% 22.4M/39.5M [00:04<00:03, 5.92MB/s]
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554187.r13i1n3:   0% 1.00k/9.32M [00:00<?, ?B/s]
#
#
#
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  69% 27.2M/39.5M [00:05<00:02, 5.57MB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:  46% 18.0M/39.5M [00:04<00:04, 4.97MB/s]
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  83% 32.7M/39.5M [00:06<00:01, 5.64MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:  59% 23.5M/39.5M [00:05<00:03, 5.24MB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:  60% 23.6M/39.5M [00:05<00:03, 5.26MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:  72% 28.5M/39.5M [00:06<00:02, 5.23MB/s]
#
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  95% 37.7M/39.5M [00:07<00:00, 5.50MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:   0% 1.00k/39.5M [00:00<?, ?B/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:  85% 33.7M/39.5M [00:07<00:01, 5.27MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:  85% 33.6M/39.5M [00:07<00:01, 5.27MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:   8% 2.97M/39.5M [00:01<00:12, 3.10MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth:  98% 38.8M/39.5M [00:08<00:00, 5.32MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  21% 8.16M/39.5M [00:02<00:07, 4.47MB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth:  98% 38.9M/39.5M [00:08<00:00, 5.33MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  30% 12.0M/39.5M [00:03<00:06, 4.25MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  55% 21.8M/39.5M [00:04<00:02, 6.62MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth:  80% 31.8M/39.5M [00:05<00:01, 8.01MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth:   0% 1.00k/39.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth:   4% 1.56M/39.5M [00:01<00:24, 1.64MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth:  28% 11.2M/39.5M [00:02<00:04, 6.60MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth:  53% 20.9M/39.5M [00:03<00:02, 8.25MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth:  77% 30.3M/39.5M [00:04<00:01, 8.86MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000282220_2311946240.pth:   0% 1.00k/39.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000282220_2311946240.pth:   1% 225k/39.5M [00:01<02:59, 229kB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000282220_2311946240.pth:  26% 10.2M/39.5M [00:02<00:04, 6.25MB/s]
#
#
#
#
#
#
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth: 100% 39.5M/39.5M [00:20<00:00, 5.50MB/s]
#
#
#
#
# Clean file replay.mp4: 100% 6.94M/6.94M [00:17<00:00, 3.74MB/s]
# Download file replay.mp4: 100% 6.94M/6.94M [00:18<00:00, 2.65MB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth: 100% 39.5M/39.5M [00:18<00:00, 5.32MB/s]
#
# Download file .summary/0/events.out.tfevents.1666554187.r13i1n3: 100% 9.32M/9.32M [00:18<00:00, 4.35MB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth: 100% 39.5M/39.5M [00:18<00:00, 5.33MB/s]
#
#
#
#
#
# Download file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth: 100% 39.5M/39.5M [00:20<00:00, 2.06MB/s]
#
# Download file replay.mp4: 100% 6.94M/6.94M [00:19<00:00, 344kB/s]
# Download file replay.mp4: 100% 6.94M/6.94M [00:19<00:00, 380kB/s]
#
#
# Download file .summary/0/events.out.tfevents.1666554187.r13i1n3: 100% 9.32M/9.32M [00:19<00:00, 370kB/s]
#
# Download file .summary/0/events.out.tfevents.1666554187.r13i1n3: 100% 9.32M/9.32M [00:19<00:00, 511kB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth: 100% 39.5M/39.5M [00:19<00:00, 945kB/s]
#
#
# Download file checkpoint_p0/checkpoint_000282220_2311946240.pth: 100% 39.5M/39.5M [00:19<00:00, 2.17MB/s]
#
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth: 100% 39.5M/39.5M [00:19<00:00, 941kB/s]
#
#
#
# Download file checkpoint_p0/checkpoint_000281648_2307260416.pth: 100% 39.5M/39.5M [00:19<00:00, 2.17MB/s]
#
#
#
#
#
# Clean file replay.mp4: 100% 6.94M/6.94M [00:18<00:00, 296kB/s]
#
#
#
#
# Clean file replay.mp4: 100% 6.94M/6.94M [00:18<00:00, 403kB/s]
#
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554187.r13i1n3: 100% 9.32M/9.32M [00:16<00:00, 538kB/s]
#
#
#
#
#
# Clean file .summary/0/events.out.tfevents.1666554187.r13i1n3: 100% 9.32M/9.32M [00:16<00:00, 609kB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth: 100% 39.5M/39.5M [00:13<00:00, 2.38MB/s]
#
#
#
#
#
#
# Clean file checkpoint_p0/best_000270111_2212749312_reward_93.067.pth: 100% 39.5M/39.5M [00:13<00:00, 3.18MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth: 100% 39.5M/39.5M [00:08<00:00, 4.39MB/s]
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000281648_2307260416.pth: 100% 39.5M/39.5M [00:08<00:00, 5.17MB/s]
#
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000282220_2311946240.pth: 100% 39.5M/39.5M [00:04<00:00, 12.9MB/s]
#
#
#
#
#
#
#
#
# Clean file checkpoint_p0/checkpoint_000282220_2311946240.pth: 100% 39.5M/39.5M [00:04<00:00, 10.3MB/s]
# [2023-05-26 04:52:18,073][28703] The repository edbeeching/doom_deathmatch_bots_2222 has been cloned to ./train_dir/doom_deathmatch_bots_2222

# %% [markdown]
# Given the agent plays for a long time the video generation can take **10 minutes**.

# %%
from sample_factory.enjoy import enjoy
register_vizdoom_components()
env = "doom_deathmatch_bots"
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=1", "--experiment=doom_deathmatch_bots_2222", "--train_dir=train_dir"], evaluation=True)
status = enjoy(cfg)
mp4 = open('/content/train_dir/doom_deathmatch_bots_2222/replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# [2023-05-26 04:54:30,362][00299] Environment doom_basic already registered, overwriting...
# [2023-05-26 04:54:30,365][00299] Environment doom_two_colors_easy already registered, overwriting...
# [2023-05-26 04:54:30,367][00299] Environment doom_two_colors_hard already registered, overwriting...
# [2023-05-26 04:54:30,369][00299] Environment doom_dm already registered, overwriting...
# [2023-05-26 04:54:30,370][00299] Environment doom_dwango5 already registered, overwriting...
# [2023-05-26 04:54:30,372][00299] Environment doom_my_way_home_flat_actions already registered, overwriting...
# [2023-05-26 04:54:30,373][00299] Environment doom_defend_the_center_flat_actions already registered, overwriting...
# [2023-05-26 04:54:30,375][00299] Environment doom_my_way_home already registered, overwriting...
# [2023-05-26 04:54:30,376][00299] Environment doom_deadly_corridor already registered, overwriting...
# [2023-05-26 04:54:30,377][00299] Environment doom_defend_the_center already registered, overwriting...
# [2023-05-26 04:54:30,378][00299] Environment doom_defend_the_line already registered, overwriting...
# [2023-05-26 04:54:30,380][00299] Environment doom_health_gathering already registered, overwriting...
# [2023-05-26 04:54:30,388][00299] Environment doom_health_gathering_supreme already registered, overwriting...
# [2023-05-26 04:54:30,389][00299] Environment doom_battle already registered, overwriting...
# [2023-05-26 04:54:30,391][00299] Environment doom_battle2 already registered, overwriting...
# [2023-05-26 04:54:30,395][00299] Environment doom_duel_bots already registered, overwriting...
# [2023-05-26 04:54:30,396][00299] Environment doom_deathmatch_bots already registered, overwriting...
# [2023-05-26 04:54:30,398][00299] Environment doom_duel already registered, overwriting...
# [2023-05-26 04:54:30,399][00299] Environment doom_deathmatch_full already registered, overwriting...
# [2023-05-26 04:54:30,400][00299] Environment doom_benchmark already registered, overwriting...
# [2023-05-26 04:54:30,401][00299] register_encoder_factory: <function make_vizdoom_encoder at 0x7f2c69341480>
# [2023-05-26 04:54:30,429][00299] Loading legacy config file train_dir/doom_deathmatch_bots_2222/cfg.json instead of train_dir/doom_deathmatch_bots_2222/config.json
# [2023-05-26 04:54:30,431][00299] Loading existing experiment configuration from train_dir/doom_deathmatch_bots_2222/config.json
# [2023-05-26 04:54:30,432][00299] Overriding arg 'experiment' with value 'doom_deathmatch_bots_2222' passed from command line
# [2023-05-26 04:54:30,433][00299] Overriding arg 'train_dir' with value 'train_dir' passed from command line
# [2023-05-26 04:54:30,435][00299] Overriding arg 'num_workers' with value 1 passed from command line
# [2023-05-26 04:54:30,437][00299] Adding new argument 'env_gpu_observations'=True that is not in the saved config file!
# [2023-05-26 04:54:30,439][00299] Adding new argument 'no_render'=True that is not in the saved config file!
# [2023-05-26 04:54:30,440][00299] Adding new argument 'save_video'=True that is not in the saved config file!
# [2023-05-26 04:54:30,448][00299] Adding new argument 'video_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:54:30,451][00299] Adding new argument 'video_name'=None that is not in the saved config file!
# [2023-05-26 04:54:30,453][00299] Adding new argument 'max_num_frames'=1000000000.0 that is not in the saved config file!
# [2023-05-26 04:54:30,457][00299] Adding new argument 'max_num_episodes'=1 that is not in the saved config file!
# [2023-05-26 04:54:30,458][00299] Adding new argument 'push_to_hub'=False that is not in the saved config file!
# [2023-05-26 04:54:30,460][00299] Adding new argument 'hf_repository'=None that is not in the saved config file!
# [2023-05-26 04:54:30,462][00299] Adding new argument 'policy_index'=0 that is not in the saved config file!
# [2023-05-26 04:54:30,464][00299] Adding new argument 'eval_deterministic'=False that is not in the saved config file!
# [2023-05-26 04:54:30,466][00299] Adding new argument 'train_script'='.usr.local.lib.python3.10.dist-packages.ipykernel_launcher' that is not in the saved config file!
# [2023-05-26 04:54:30,468][00299] Using frameskip 1 and render_action_repeat=4 for evaluation
# [2023-05-26 04:54:30,493][00299] Port 40300 is available
# [2023-05-26 04:54:30,495][00299] Using port 40300
# [2023-05-26 04:54:30,498][00299] RunningMeanStd input shape: (23,)
# [2023-05-26 04:54:30,500][00299] RunningMeanStd input shape: (3, 72, 128)
# [2023-05-26 04:54:30,502][00299] RunningMeanStd input shape: (1,)
# [2023-05-26 04:54:30,519][00299] ConvEncoder: input_channels=3
# [2023-05-26 04:54:30,555][00299] Conv encoder output size: 512
# [2023-05-26 04:54:30,556][00299] Policy head output size: 512
# [2023-05-26 04:54:30,582][00299] Loading state from checkpoint train_dir/doom_deathmatch_bots_2222/checkpoint_p0/checkpoint_000282220_2311946240.pth...
# [2023-05-26 04:54:30,616][00299] Using port 40300 on host...
# [2023-05-26 04:54:30,956][00299] Initialized w:0 v:0 player:0
# [2023-05-26 04:54:48,681][00299] DAMAGECOUNT value on done: 7520.0
# [2023-05-26 04:54:48,685][00299] Sum rewards: 108.066, reward structure: {'DEATHCOUNT': '-12.000', 'HEALTH': '-4.960', 'AMMO2': '0.001', 'AMMO5': '0.003', 'AMMO4': '0.007', 'WEAPON4': '0.100', 'WEAPON5': '0.100', 'weapon5': '0.198', 'AMMO3': '0.214', 'weapon4': '0.816', 'weapon2': '1.540', 'WEAPON3': '1.600', 'HITCOUNT': '4.240', 'weapon3': '13.646', 'DAMAGECOUNT': '22.560', 'FRAGCOUNT': '80.000'}
# [2023-05-26 04:54:48,749][00299] Avg episode rewards: #0: 108.060, true rewards: #0: 80.000
# [2023-05-26 04:54:48,751][00299] Avg episode reward: 108.060, avg true_objective: 80.000

# %% [markdown]
# You **can try to train your agent in this environment** using the code above, but not on colab.
# **Good luck 🤞**

# %% [markdown]
# If you prefer an easier scenario, **why not try training in another ViZDoom scenario such as `doom_deadly_corridor` or `doom_defend_the_center`.**
#
#
#
# ---
#
#
# This concludes the last unit. But we are not finished yet! 🤗 The following **bonus section include some of the most interesting, advanced and cutting edge work in Deep Reinforcement Learning**.
#
# ## Keep learning, stay awesome 🤗
