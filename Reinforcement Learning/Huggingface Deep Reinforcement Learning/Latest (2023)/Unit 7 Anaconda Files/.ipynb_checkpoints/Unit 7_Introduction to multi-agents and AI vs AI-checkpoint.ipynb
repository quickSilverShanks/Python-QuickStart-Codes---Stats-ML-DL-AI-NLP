# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# !git config --system core.longpaths true

# %%
# !git clone --branch aivsai https://github.com/huggingface/ml-agents
# Out:
# Cloning into 'ml-agents'...
# Updating files:   7% (169/2159)
# Updating files:   8% (173/2159)
# Updating files:   9% (195/2159)
# Updating files:  10% (216/2159)
# Updating files:  11% (238/2159)
# Updating files:  12% (260/2159)
# Updating files:  13% (281/2159)
# Updating files:  14% (303/2159)
# Updating files:  14% (323/2159)
# Updating files:  15% (324/2159)
# Updating files:  16% (346/2159)
# Updating files:  17% (368/2159)
# Updating files:  18% (389/2159)
# Updating files:  19% (411/2159)
# Updating files:  20% (432/2159)
# Updating files:  21% (454/2159)
# Updating files:  22% (475/2159)
# Updating files:  23% (497/2159)
# Updating files:  24% (519/2159)
# Updating files:  25% (540/2159)
# Updating files:  26% (562/2159)
# Updating files:  27% (583/2159)
# Updating files:  28% (605/2159)
# Updating files:  29% (627/2159)
# Updating files:  30% (648/2159)
# Updating files:  31% (670/2159)
# Updating files:  32% (691/2159)
# Updating files:  33% (713/2159)
# ...

# %%
# !pwd
# Out:
# /d/GitHub/Python-QuickStart-Codes---Stats-ML-DL-AI-NLP/Reinforcement Learning/Huggingface Deep Reinforcement Learning/Latest (2023)/Unit 7 Anaconda Files

# %%
# %cd ml-agents
# !pip install -e ./ml-agents-envs
# !pip install -e ./ml-agents
# Out:
# D:\GitHub\Python-QuickStart-Codes---Stats-ML-DL-AI-NLP\Reinforcement Learning\Huggingface Deep Reinforcement Learning\Latest (2023)\Unit 7 Anaconda Files\ml-agents
# Obtaining file:///D:/GitHub/Python-QuickStart-Codes---Stats-ML-DL-AI-NLP/Reinforcement%20Learning/Huggingface%20Deep%20Reinforcement%20Learning/Latest%20%282023%29/Unit%207%20Anaconda%20Files/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB 435.7 kB/s eta 0:00:10
#      ---------------------------------------- 0.0/4.1 MB 393.8 kB/s eta 0:00:11
#      ---------------------------------------- 0.0/4.1 MB 393.8 kB/s eta 0:00:11
#      ---------------------------------------- 0.0/4.1 MB 393.8 kB/s eta 0:00:11
# ...

# %%
# !pip install torch
# Out:
# ...
#      ---------------------------------------- 0.0/172.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/172.4 MB 325.1 kB/s eta 0:08:51
#      -------------------------------------- 0.0/172.4 MB 325.1 kB/s eta 0:08:51
#      -------------------------------------- 0.0/172.4 MB 325.1 kB/s eta 0:08:51
#      -------------------------------------- 0.0/172.4 MB 325.1 kB/s eta 0:08:51
#      -------------------------------------- 0.0/172.4 MB 325.1 kB/s eta 0:08:51
#      -------------------------------------- 0.0/172.4 MB 115.5 kB/s eta 0:24:53
#      -------------------------------------- 0.1/172.4 MB 170.7 kB/s eta 0:16:50
#      -------------------------------------- 0.1/172.4 MB 209.5 kB/s eta 0:13:43
#      -------------------------------------- 0.1/172.4 MB 242.7 kB/s eta 0:11:50
#      -------------------------------------- 0.1/172.4 MB 242.7 kB/s eta 0:11:50
# ...

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=3ccc2d5436e647d53acc9178c156bba952cfbd66528be924c26143b889fe8dc7
#   Stored in directory: c:\users\shashank prakash\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...

# %%
# !mkdir "./training-envs-executables"

# %%
# Below command doesn't work. Manually copy the SoccerTwos files unzipped into this folder.

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1sqFxbEdTMubjVktnV4C6ICjp89wLhUcP' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1sqFxbEdTMubjVktnV4C6ICjp89wLhUcP" -O SoccerTwos.zip && rm -rf /tmp/cookies.txt

# %%
# File manually unzipped.

# !unzip -d ./training-envs-executables/ ./SoccerTwos.zip

# %%
# !pwd
# Out:
# /d/GitHub/Python-QuickStart-Codes---Stats-ML-DL-AI-NLP/Reinforcement Learning/Huggingface Deep Reinforcement Learning/Latest (2023)/Unit 7 Anaconda Files/ml-agents

# %%
# This is required for Linux, i believe, not for windows.

# !chmod -R 755 ./training-envs-executables/SoccerTwos_Data

# %%
# There has been a breaking change in protobuf so using older version that works with mlagent and onnx both.
# !pip install protobuf==3.20.2
# Out:
# ...
#      ---------------------------------------- 0.0/904.2 kB ? eta -:--:--
#      ---------------------------------------- 10.2/904.2 kB ? eta -:--:--
#      - ----------------------------------- 30.7/904.2 kB 330.3 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/904.2 kB 330.3 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/904.2 kB 330.3 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/904.2 kB 330.3 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/904.2 kB 330.3 kB/s eta 0:00:03
#      -- ---------------------------------- 61.4/904.2 kB 172.4 kB/s eta 0:00:05
#      --- --------------------------------- 81.9/904.2 kB 209.0 kB/s eta 0:00:04
#      ---- ------------------------------- 112.6/904.2 kB 262.6 kB/s eta 0:00:04
#      ---- ------------------------------- 112.6/904.2 kB 262.6 kB/s eta 0:00:04
#      ---- ------------------------------- 112.6/904.2 kB 262.6 kB/s eta 0:00:04
# ...

# %%
# !pip install onnx

# %%
# !mlagents-learn ./config/poca/SoccerTwos.yaml --env=./training-envs-executables/SoccerTwos.exe --run-id="SoccerTwos_run3" --no-graphics
# Out:
# [INFO] Connected to Unity environment with package version 2.3.0-exp.3 and communication version 1.5.0
# [INFO] Connected new brain: SoccerTwos?team=1
# [INFO] Connected new brain: SoccerTwos?team=0
#
#
# 	Unity Technologies
#
#  Version information:
#   ml-agents: 0.31.0.dev0,
#   ml-agents-envs: 0.31.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.0.1+cpu
# [INFO] Hyperparameters for behavior name SoccerTwos:
# 	trainer_type:	poca
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  learning_rate_schedule:	constant
# 	  beta_schedule:	constant
# 	  epsilon_schedule:	constant
# 	checkpoint_interval:	500000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# ...

# %%
# !huggingface-cli login

from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store
# Out:
# Login successful
# Your token has been saved to C:\Users\Shashank Prakash\.huggingface\token

# %%
# !pip install git-lfs

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !mlagents-push-to-hf  --run-id="SoccerTwos_run3" --local-dir="./results/SoccerTwos_run3" --repo-id="QuickSilver007/rlv2unit7_poca-SoccerTwos" --commit-message="First Push, trained on i7 8th gen CPU for 5M timesteps"`
# Out:
# SoccerTwos_run3
# QuickSilver007/rlv2unit7_poca-SoccerTwos
# This function will create a model card and upload your SoccerTwos_run3 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  rlv2unit7_poca-SoccerTwos
# ORGANIZATION:  QuickSilver007
# Traceback (most recent call last):
#   File "D:\Installed Programs\anaconda3\envs\rl_soccertwos\lib\site-packages\huggingface_hub\repository.py", line 574, in check_git_versions
#     lfs_version = run_subprocess("git-lfs --version", self.local_dir).stdout.strip()
#   File "D:\Installed Programs\anaconda3\envs\rl_soccertwos\lib\site-packages\huggingface_hub\utils\_subprocess.py", line 83, in run_subprocess
#     return subprocess.run(
#   File "D:\Installed Programs\anaconda3\envs\rl_soccertwos\lib\subprocess.py", line 505, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "D:\Installed Programs\anaconda3\envs\rl_soccertwos\lib\subprocess.py", line 951, in __init__
# ...
