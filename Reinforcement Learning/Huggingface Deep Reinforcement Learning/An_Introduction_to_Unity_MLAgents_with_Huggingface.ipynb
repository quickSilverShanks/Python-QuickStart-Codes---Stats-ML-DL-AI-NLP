# %% [markdown]
# ## Introduction to Unity MLAgents using Huggingface

# %% [markdown]
# The notebook is based on the article which is a part of Deep RL Course. The Unity MLA article is in below location:<br>
# https://thomassimonini.medium.com/an-introduction-to-unity-ml-agents-with-hugging-face-efbac62c8c80

# %% [markdown]
# #### Step 01 : Clone and install the Hugging Face ML-Agents fork

# %%
# Clone the repository 
# !git clone https://github.com/huggingface/ml-agents/
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 84252, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 84252 (delta 78), reused 144 (delta 48), pack-reused 84051
# Receiving objects: 100% (84252/84252), 2.48 GiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (61524/61524), done.
# Checking out files: 100% (2106/2106), done.

# %%
# Go inside the repository
# %cd /content/ml-agents
# Out:
# /content/ml-agents

# %%
# install the package
# !pip3 install -e ./ml-agents-envs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/ml-agents/ml-agents-envs
# ...
#   Running setup.py develop for mlagents-envs
# ...

# %%
# install the package
# !pip3 install -e ./ml-agents
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/ml-agents/ml-agents
# ...
#      |████████████████████████████████| 101 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 804.1 MB 2.7 kB/s
# ...
#      |████████████████████████████████| 596 kB 48.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Running setup.py develop for mlagents
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# ...

# %% [markdown]
# #### Step 02 : Copy environment executables in 'trained-envs-executables/linux'
# --and modify max_steps in config/ppo/PyramidsRND.yaml to 1000000

# %%
# !unzip "/content/Pyramids.zip" -d "/content/ml-agents/trained-envs-executables/linux"
# Out:
# Archive:  /content/Pyramids.zip
#    creating: /content/ml-agents/trained-envs-executables/linux/Pyramids/
#   inflating: /content/ml-agents/trained-envs-executables/linux/Pyramids/UnityPlayer.so
#   inflating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids
#    creating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/
#    creating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/Data/
#    creating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/Data/Plugins/
#   inflating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/Data/Plugins/lib_burst_generated.txt
#    creating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids_Data/
#   inflating: /content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids_Data/resources.assets
# ...

# %% [markdown]
# #### Step 03 : Train our Agent

# %%
import os
os.getcwd()
# Out:
# '/content/ml-agents'

# %%
# !mlagents-learn /content/ml-agents/config/ppo/PyramidsRND.yaml --env=/content/ml-agents/trained-envs-executables/linux/Pyramids/Pyramids --run-id="First Training" --force --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# ...

# %%
# !tensorboard --logdir results --port 6006
# Out:
# 2022-06-25 09:26:34.491193: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.8.0 at http://localhost:6006/ (Press CTRL+C to quit)
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/util.py", line 320, in _exit_function
#     def _exit_function(info=info, debug=debug, _run_finalizers=_run_finalizers,
# KeyboardInterrupt

# %% [markdown]
# #### Step 04 : Push the Agent ot the Hub

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# ...

# %%
# !mlagents-push-to-hf --run-id="First Training" --local-dir="results/First Training" --repo-id="QuickSilver007/MLAgents-Pyramids" --commit-message="Trained Pyramids agent upload"
# Out:
# First Training
# QuickSilver007/MLAgents-Pyramids
# This function will create a model card and upload your First Training into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  MLAgents-Pyramids
# ORGANIZATION:  QuickSilver007
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:94: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.10. Pass `repo_id` instead.
#   FutureWarning,
# Cloning https://huggingface.co/QuickSilver007/MLAgents-Pyramids into local empty directory.
# Upload file Pyramids/Pyramids-1000061.pt:   0% 3.34k/8.25M [00:00<?, ?B/s]
# Upload file Pyramids/Pyramids-999933.pt:   0% 3.34k/8.25M [00:00<?, ?B/s]
#
# Upload file Pyramids/Pyramids-499903.onnx:   0% 3.34k/1.35M [00:00<?, ?B/s]
#
# Upload file Pyramids/Pyramids-499903.onnx:  24% 327k/1.35M [00:01<00:03, 331kB/s]
# Upload file Pyramids/Pyramids-1000061.pt:   2% 143k/8.25M [00:01<00:59, 143kB/s]
# ...
